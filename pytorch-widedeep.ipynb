# %%
# !pip install pytorch-widedeep
# !pip install -r widedeep_requirements.txt
# Out:
# Requirement already satisfied: pytorch-widedeep in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (1.0.13)
# Requirement already satisfied: opencv-contrib-python in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (4.5.5.62)
# Requirement already satisfied: torch in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (1.6.0)
# Requirement already satisfied: torchmetrics in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (0.6.2)
# Requirement already satisfied: einops in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (0.3.2)
# Requirement already satisfied: gensim in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (4.1.2)
# Requirement already satisfied: ray[tune] in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (1.9.1)
# Requirement already satisfied: scikit-learn in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (0.23.2)
# Requirement already satisfied: torchvision in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (0.7.0)
# Requirement already satisfied: wrapt in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (1.12.1)
# Requirement already satisfied: scipy in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (1.5.2)
# Requirement already satisfied: spacy in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (3.2.1)
# Requirement already satisfied: imutils in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (0.5.4)
# Requirement already satisfied: numpy>=1.20.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (1.22.0)
# Requirement already satisfied: pandas in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (1.1.3)
# Requirement already satisfied: tqdm in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pytorch-widedeep) (4.50.2)
# Requirement already satisfied: future in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from torch->pytorch-widedeep) (0.18.2)
# Requirement already satisfied: packaging in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from torchmetrics->pytorch-widedeep) (20.4)
# Requirement already satisfied: smart-open>=1.8.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from gensim->pytorch-widedeep) (5.2.1)
# Requirement already satisfied: protobuf>=3.15.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (3.19.1)
# Requirement already satisfied: filelock in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (3.0.12)
# Requirement already satisfied: click>=7.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (7.1.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (1.0.0)
# Requirement already satisfied: redis>=3.5.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (4.1.0)
# Requirement already satisfied: jsonschema in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (3.2.0)
# Requirement already satisfied: grpcio>=1.28.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (1.32.0)
# Requirement already satisfied: pyyaml in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (5.3.1)
# Requirement already satisfied: attrs in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (20.3.0)
# Requirement already satisfied: tensorboardX>=1.9; extra == "tune" in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (2.4.1)
# Requirement already satisfied: tabulate; extra == "tune" in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (0.8.9)
# Requirement already satisfied: requests; extra == "tune" in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->pytorch-widedeep) (2.24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from scikit-learn->pytorch-widedeep) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from scikit-learn->pytorch-widedeep) (0.17.0)
# Requirement already satisfied: pillow>=4.1.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from torchvision->pytorch-widedeep) (8.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (0.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (3.3.0)
# Requirement already satisfied: jinja2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (2.11.2)
# Requirement already satisfied: pathy>=0.3.5 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (0.6.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (8.0.13)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (3.0.8)
# Requirement already satisfied: setuptools in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (50.3.1.post20201107)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (0.7.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (1.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (2.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (1.8.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->pytorch-widedeep) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pandas->pytorch-widedeep) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pandas->pytorch-widedeep) (2020.1)
# Requirement already satisfied: six in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from packaging->torchmetrics->pytorch-widedeep) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from packaging->torchmetrics->pytorch-widedeep) (2.4.7)
# Requirement already satisfied: deprecated>=1.2.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from redis>=3.5.0->ray[tune]->pytorch-widedeep) (1.2.13)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from jsonschema->ray[tune]->pytorch-widedeep) (0.17.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests; extra == "tune"->ray[tune]->pytorch-widedeep) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests; extra == "tune"->ray[tune]->pytorch-widedeep) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests; extra == "tune"->ray[tune]->pytorch-widedeep) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests; extra == "tune"->ray[tune]->pytorch-widedeep) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from jinja2->spacy->pytorch-widedeep) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy->pytorch-widedeep) (3.7.4.3)
# Requirement already satisfied: pandas in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: numpy in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: scipy in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: scikit-learn in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 7)) (0.23.2)
# Requirement already satisfied: gensim in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 9)) (4.1.2)
# Requirement already satisfied: spacy in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 11)) (3.2.1)
# Requirement already satisfied: opencv-contrib-python in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 13)) (4.5.5.62)
# Requirement already satisfied: imutils in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 15)) (0.5.4)
# Requirement already satisfied: tqdm in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 17)) (4.50.2)
# Requirement already satisfied: torch in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 19)) (1.6.0)
# Requirement already satisfied: torchvision in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 21)) (0.7.0)
# Requirement already satisfied: einops in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 23)) (0.3.2)
# Requirement already satisfied: wrapt in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 25)) (1.12.1)
# Requirement already satisfied: torchmetrics in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 27)) (0.6.2)
# Requirement already satisfied: ray[tune] in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from -r widedeep_requirements.txt (line 29)) (1.9.1)
# Requirement already satisfied: pytz>=2017.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pandas->-r widedeep_requirements.txt (line 1)) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pandas->-r widedeep_requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from scikit-learn->-r widedeep_requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from scikit-learn->-r widedeep_requirements.txt (line 7)) (0.17.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from gensim->-r widedeep_requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (8.0.13)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (2.24.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (3.0.8)
# Requirement already satisfied: setuptools in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (50.3.1.post20201107)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (2.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (20.4)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (0.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (2.0.6)
# Requirement already satisfied: jinja2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from spacy->-r widedeep_requirements.txt (line 11)) (2.11.2)
# Requirement already satisfied: future in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from torch->-r widedeep_requirements.txt (line 19)) (0.18.2)
# Requirement already satisfied: pillow>=4.1.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from torchvision->-r widedeep_requirements.txt (line 21)) (8.0.1)
# Requirement already satisfied: protobuf>=3.15.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (3.19.1)
# Requirement already satisfied: grpcio>=1.28.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (1.32.0)
# Requirement already satisfied: jsonschema in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (3.2.0)
# Requirement already satisfied: attrs in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (20.3.0)
# Requirement already satisfied: pyyaml in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (5.3.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (1.0.0)
# Requirement already satisfied: filelock in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (3.0.12)
# Requirement already satisfied: redis>=3.5.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (4.1.0)
# Requirement already satisfied: click>=7.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (7.1.2)
# Requirement already satisfied: tabulate; extra == "tune" in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (0.8.9)
# Requirement already satisfied: tensorboardX>=1.9; extra == "tune" in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from ray[tune]->-r widedeep_requirements.txt (line 29)) (2.4.1)
# Requirement already satisfied: six>=1.5 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->-r widedeep_requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r widedeep_requirements.txt (line 11)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r widedeep_requirements.txt (line 11)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r widedeep_requirements.txt (line 11)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r widedeep_requirements.txt (line 11)) (1.25.11)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from packaging>=20.0->spacy->-r widedeep_requirements.txt (line 11)) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy->-r widedeep_requirements.txt (line 11)) (3.7.4.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from jinja2->spacy->-r widedeep_requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from jsonschema->ray[tune]->-r widedeep_requirements.txt (line 29)) (0.17.3)
# Requirement already satisfied: deprecated>=1.2.3 in /home/isds/.conda/envs/isds/lib/python3.8/site-packages (from redis>=3.5.0->ray[tune]->-r widedeep_requirements.txt (line 29)) (1.2.13)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from pytorch_widedeep import Trainer
from pytorch_widedeep.preprocessing import WidePreprocessor, TabPreprocessor
from pytorch_widedeep.models import Wide, TabMlp, WideDeep
from pytorch_widedeep.metrics import Accuracy, Precision, F1Score

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

print(train_df.shape)
train_df.head(3)
# Out:
# (501951, 35)
#    id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0   0          True          True          True         False         False
# 1   1         False         False         False          True          True
# 2   2         False         False         False          True         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_1  person_attribute_b  \
# 0         False                   1                     4                   3
# 1         False                   1                     3                   4
# 2         False                   2                     0                   3
#
#    ...  contents_attribute_k  contents_attribute_l  contents_attribute_d  \
# 0  ...                     2                  1608                   275
# 1  ...                     2                  1608                   275
# 2  ...                     1                  1600                    94
#
#    contents_attribute_m  contents_attribute_e  contents_attribute_h  \
# 0                     1                     4                   139
# 1                     1                     4                   133
# 2                     1                     4                    53
#
#    person_rn  contents_rn     contents_open_dt  target
# 0     618822       354805  2020-01-17 12:09:36       1
# 1     571659       346213  2020-06-18 17:48:52       0
# 2     399816       206408  2020-07-08 20:00:10       0
#
# [3 rows x 35 columns]

# %%
wide_cols = [
'contents_attribute_a',
 'contents_attribute_c',
 'contents_attribute_d',
 'contents_attribute_e',
 'contents_attribute_h',
 'contents_attribute_i',
 'contents_attribute_j',
 'contents_attribute_j_1',
 'contents_attribute_k',
 'contents_attribute_l',
 'contents_attribute_m',
 'd_l_match_yn',
 'd_m_match_yn',
 'd_s_match_yn',
 'h_l_match_yn',
 'h_m_match_yn',
 'h_s_match_yn',
 'person_attribute_a',
 'person_attribute_a_1',
 'person_attribute_b',
 'person_prefer_c',
 'person_prefer_d_1',
 'person_prefer_d_2',
 'person_prefer_d_3',
 'person_prefer_e',
 'person_prefer_h_1',
 'person_prefer_h_2',
 'person_prefer_h_3'
]
crossed_cols = None # [("education", "occupation"), ("native_country", "occupation")]
cat_embed_cols = [
('contents_attribute_a',16),
 ('contents_attribute_c',16),
 ('contents_attribute_d',16),
 ('contents_attribute_e',16),
 ('contents_attribute_h',16),
 ('contents_attribute_i',16),
 ('contents_attribute_j',16),
 ('contents_attribute_j_1',16),
 ('contents_attribute_k',16),
 ('contents_attribute_l',16),
 ('contents_attribute_m',16),
 ('d_l_match_yn',16),
 ('d_m_match_yn',16),
 ('d_s_match_yn',16),
 ('h_l_match_yn',16),
 ('h_m_match_yn',16),
 ('h_s_match_yn',16),
 ('person_attribute_a',16),
 ('person_attribute_a_1',16),
 ('person_attribute_b',16),
 ('person_prefer_c',16),
 ('person_prefer_d_1',16),
 ('person_prefer_d_2',16),
 ('person_prefer_d_3',16),
 ('person_prefer_e',16),
 ('person_prefer_h_1',16),
 ('person_prefer_h_2',16),
 ('person_prefer_h_3',16)
]
continuous_cols = None #["age", "hours_per_week"]
target_col = "target"

# %%
# TARGET
target = train_df[target_col].values

# wide
wide_preprocessor = WidePreprocessor(wide_cols=wide_cols, crossed_cols=crossed_cols)
X_wide = wide_preprocessor.fit_transform(train_df)

# deeptabular
tab_preprocessor = TabPreprocessor(
    embed_cols=cat_embed_cols, continuous_cols=continuous_cols
)
X_tab = tab_preprocessor.fit_transform(train_df)

# %%
X_wide
# Out:
# array([[   1,    4,    8, ..., 6370, 6649, 6928],
#        [   1,    4,    8, ..., 6371, 6650, 6929],
#        [   2,    4,    9, ..., 6372, 6651, 6930],
#        ...,
#        [   2,    4,  172, ..., 6387, 6657, 6935],
#        [   3,    4,  172, ..., 6410, 6660, 6933],
#        [   1,    4,  172, ..., 6438, 6727, 6969]])

# %%
X_tab
# Out:
# array([[  1,   1,   1, ...,   1,   1,   1],
#        [  1,   1,   1, ...,   2,   2,   2],
#        [  2,   1,   2, ...,   3,   3,   3],
#        ...,
#        [  2,   1, 165, ...,  18,   9,   8],
#        [  3,   1, 165, ...,  41,  12,   6],
#        [  1,   1, 165, ...,  69,  79,  42]])

# %%
wide = Wide(wide_dim=np.unique(X_wide).shape[0], pred_dim=1)
deeptabular = TabMlp(
    mlp_hidden_dims=[64, 32],
    column_idx=tab_preprocessor.column_idx,
    embed_input=tab_preprocessor.embeddings_input,
    continuous_cols=continuous_cols,
)
model = WideDeep(wide=wide, deeptabular=deeptabular)

# %%
model
# Out:
# WideDeep(
#   (wide): Wide(
#     (wide_linear): Embedding(7207, 1, padding_idx=0)
#   )
#   (deeptabular): Sequential(
#     (0): TabMlp(
#       (cat_embed_and_cont): CatEmbeddingsAndCont(
#         (embed_layers): ModuleDict(
#           (emb_layer_contents_attribute_a): Embedding(4, 16, padding_idx=0)
#           (emb_layer_contents_attribute_c): Embedding(5, 16, padding_idx=0)
#           (emb_layer_contents_attribute_d): Embedding(1066, 16, padding_idx=0)
#           (emb_layer_contents_attribute_e): Embedding(13, 16, padding_idx=0)
#           (emb_layer_contents_attribute_h): Embedding(251, 16, padding_idx=0)
#           (emb_layer_contents_attribute_i): Embedding(4, 16, padding_idx=0)
#           (emb_layer_contents_attribute_j): Embedding(3, 16, padding_idx=0)
#           (emb_layer_contents_attribute_j_1): Embedding(10, 16, padding_idx=0)
#           (emb_layer_contents_attribute_k): Embedding(3, 16, padding_idx=0)
#           (emb_layer_contents_attribute_l): Embedding(1753, 16, padding_idx=0)
#           (emb_layer_contents_attribute_m): Embedding(6, 16, padding_idx=0)
#           (emb_layer_d_l_match_yn): Embedding(3, 16, padding_idx=0)
#           (emb_layer_d_m_match_yn): Embedding(3, 16, padding_idx=0)
#           (emb_layer_d_s_match_yn): Embedding(3, 16, padding_idx=0)
#           (emb_layer_h_l_match_yn): Embedding(3, 16, padding_idx=0)
#           (emb_layer_h_m_match_yn): Embedding(3, 16, padding_idx=0)
#           (emb_layer_h_s_match_yn): Embedding(3, 16, padding_idx=0)
#           (emb_layer_person_attribute_a): Embedding(3, 16, padding_idx=0)
#           (emb_layer_person_attribute_a_1): Embedding(9, 16, padding_idx=0)
#           (emb_layer_person_attribute_b): Embedding(7, 16, padding_idx=0)
#           (emb_layer_person_prefer_c): Embedding(6, 16, padding_idx=0)
#           (emb_layer_person_prefer_d_1): Embedding(1094, 16, padding_idx=0)
#           (emb_layer_person_prefer_d_2): Embedding(1082, 16, padding_idx=0)
#           (emb_layer_person_prefer_d_3): Embedding(1044, 16, padding_idx=0)
#           (emb_layer_person_prefer_e): Embedding(13, 16, padding_idx=0)
#           (emb_layer_person_prefer_h_1): Embedding(280, 16, padding_idx=0)
#           (emb_layer_person_prefer_h_2): Embedding(280, 16, padding_idx=0)
#           (emb_layer_person_prefer_h_3): Embedding(280, 16, padding_idx=0)
#         )
#         (embedding_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (tab_mlp): MLP(
#         (mlp): Sequential(
#           (dense_layer_0): Sequential(
#             (0): Dropout(p=0.1, inplace=False)
#             (1): Linear(in_features=448, out_features=64, bias=True)
#             (2): ReLU(inplace=True)
#           )
#           (dense_layer_1): Sequential(
#             (0): Dropout(p=0.1, inplace=False)
#             (1): Linear(in_features=64, out_features=32, bias=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (1): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
trainer = Trainer(model, objective="binary", metrics=[F1Score, Accuracy, Precision])

# %%
trainer.fit(
    X_wide=X_wide, X_tab=X_tab, target=target, n_epochs=5, batch_size=64, val_split=0.2
)
# Out:
# /home/isds/.conda/envs/isds/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /home/isds/.conda/envs/isds/lib/python3.8/site-packages/sklearn/utils/__init__.py:1102: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# epoch 1:   0%|          | 0/6275 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-1c0f6a3fd1a3> in <module>
# ----> 1 trainer.fit(
#       2     X_wide=X_wide, X_tab=X_tab, target=target, n_epochs=5, batch_size=64, val_split=0.2
#       3 ).to('cpu')
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/utils/general_utils.py in __call__(self, wrapped, instance, args, kwargs)
#      59                     self.primary_name
#      60                 ] = alias
# ---> 61         return wrapped(*args, **kwargs)
#      62
#      63
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/training/trainer.py in fit(self, X_wide, X_tab, X_text, X_img, X_train, X_val, val_split, target, n_epochs, validation_freq, batch_size, custom_dataloader, finetune, finetune_epochs, finetune_max_lr, finetune_deeptabular_gradual, finetune_deeptabular_max_lr, finetune_deeptabular_layers, finetune_deeptext_gradual, finetune_deeptext_max_lr, finetune_deeptext_layers, finetune_deepimage_gradual, finetune_deepimage_max_lr, finetune_deepimage_layers, finetune_routine, stop_after_finetuning, **kwargs)
#     615                 for batch_idx, (data, targett) in zip(t, train_loader):
#     616                     t.set_description("epoch %i" % (epoch + 1))
# --> 617                     train_score, train_loss = self._train_step(data, targett, batch_idx)
#     618                     print_loss_and_metric(t, train_loss, train_score)
#     619                     self.callback_container.on_batch_end(batch=batch_idx)
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/training/trainer.py in _train_step(self, data, target, batch_idx)
#    1162
#    1163         self.optimizer.zero_grad()
# -> 1164         y_pred = self.model(X)
#    1165         if self.model.is_tabnet:
#    1166             loss = self.loss_fn(y_pred[0], y) - self.lambda_sparse * y_pred[1]
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/models/wide_deep.py in forward(self, X)
#     188
#     189     def forward(self, X: Dict[str, Tensor]):
# --> 190         wide_out = self._forward_wide(X)
#     191         if self.deephead:
#     192             deep = self._forward_deephead(X, wide_out)
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/models/wide_deep.py in _forward_wide(self, X)
#     251     def _forward_wide(self, X):
#     252         if self.wide is not None:
# --> 253             out = self.wide(X["wide"])
#     254         else:
#     255             batch_size = X[list(X.keys())[0]].size(0)
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/.conda/envs/isds/lib/python3.8/site-packages/pytorch_widedeep/models/wide.py in forward(self, X)
#      58         r"""Forward pass. Simply connecting the Embedding layer with the ouput
#      59         neuron(s)"""
# ---> 60         out = self.wide_linear(X.long()).sum(dim=1) + self.bias
#      61         return out
#
# RuntimeError: CUDA error: no kernel image is available for execution on the device
